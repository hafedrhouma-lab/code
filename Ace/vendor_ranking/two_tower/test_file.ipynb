# %%
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/andreiromanov/DEV/talabat/Ace/omar_service.json"
os.environ["GCP_PROJECT"] = "tlb-data-dev"

# %%
from model_artifacts import ArtifactsManager
import os
import pandas as pd
import numpy as np

# TODO 1: script to load user model
# TODO 2: script to load chain model

# loading time
# 1. you define an instance of Artifacts Manager (country, version, recall)
# 2. download the model artifacts
# 3.a load user model
# 3.b update ese embeddings (from postgresql retrieve ese embeddings for a country and update it)
# 4. loop for all countries

# Inference
# given a user, time, location
# 1. retrieve static features
# 2. append order_hour, order_weekday, geohash6
# 3. route these features to the right model depending on request country
# 4. compute distance with available chains --> intersection(country chains, available chains)
# 5. replicating previous logic
# 6. penalizing previous orders with k positions


config = {"country": "AE", "recall": 3235, "version": 2}


def get_inference_path(country):
    base_path = os.path.join(os.getcwd(), f"inference_model_artifacts/{country}")
    if not os.path.exists(base_path):
        os.makedirs(base_path, exist_ok=True)
    return base_path


base_path = get_inference_path(config["country"])
artifacts_manager = VendorArtifactsManager(
    recall=config["recall"], base_dir=base_path, country=config["country"], version=config["version"]
)
artifacts_manager.download_model_artifacts()
user_model = artifacts_manager.load_user_model()
chain_model = artifacts_manager.load_chain_model()

query_features = artifacts_manager.get_query_features()
test_df = artifacts_manager.get_test_sample()
inferred_user_embedding = user_model(test_df[query_features]).numpy()

candidates_features = artifacts_manager.get_candidates_features()
chain_features = artifacts_manager.get_chain_features()
chain_embeddings = artifacts_manager.get_embeddings()
loaded_chain_embeddings = np.array([a for a in chain_embeddings.chain_embeddings.values])
inferred_chain_embeddings = chain_model(chain_features[candidates_features]).numpy()
path = artifacts_manager.base_local_dir + "/" + artifacts_manager.user_embeddings_file
loaded_user_embedding = np.array([a for a in pd.read_parquet(path).user_embeddings.values])
print(np.allclose(loaded_user_embedding, inferred_user_embedding))
print(np.allclose(inferred_chain_embeddings, loaded_chain_embeddings))
# Out:
# WARNING:root:Expecting value: line 1 column 1 (char 0)
# Downloading model weights
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_user_model_weights_recall@10_3235.data-00000-of-00001 from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_user_model_weights_recall@10_3235.data-00000-of-00001.
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_user_model_weights_recall@10_3235.index from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_user_model_weights_recall@10_3235.index.
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_user_model_params_recall@10_3235.pkl from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_user_model_params_recall@10_3235.pkl.
# Downloading chain model weights
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_chain_model_weights_recall@10_3235.data-00000-of-00001 from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_chain_model_weights_recall@10_3235.data-00000-of-00001.
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_chain_model_weights_recall@10_3235.index from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_chain_model_weights_recall@10_3235.index.
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_user_model_params_recall@10_3235.pkl from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_user_model_params_recall@10_3235.pkl.
# Downloading chain features
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_chain_features_recall@10_3235.parquet from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_chain_features_recall@10_3235.parquet.
# Downloading chain embeddings
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_chain_embeddings_recall@10_3235.parquet from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_chain_embeddings_recall@10_3235.parquet.
# Downloading user embeddings
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/tt_user_embeddings_recall@10_3235.parquet from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/tt_user_embeddings_recall@10_3235.parquet.
# Downloading test sample features
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/streamlit_3235_test_df.parquet from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/streamlit_3235_test_df.parquet.
# Downloading chain_names
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/chain_names_3235_df.parquet from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/chain_names_3235_df.parquet.
# Downloading ese chain embeddings initial weights
# Downloaded storage object twotower_v2/AE/model_artifacts_recall_3235/ese_chains_embeddings_3235.parquet from bucket tlb-data-dev-data-algorithms-content-optimization to local file /Users/andreiromanov/DEV/talabat/Ace/vendor_ranking/two_tower/inference_model_artifacts/AE/ese_chains_embeddings_3235.parquet.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=['664668 664636 664579']. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=['664699']. Consider rewriting this model with the Functional API.
# created layer
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                       user_prev_chains  \
# 0     9876 1106 617960 25817 636322 7043 7614 619528...
# 1     26225 11877 28504 636829 28504 24210 629162 25...
# 2     10756 18574 10465 655413 661432 647662 13265 1...
# 3     1991 1991 655089 2000 655087 10694 620198 1069...
# 4     638192 608113 6501 621527 600608 12709 621527 ...
# ...                                                 ...
# 9995                                      655703 655703
# 9996  931 3288 10756 931 27063 621006 931 931 10406 ...
# 9997  10756 649695 649695 637922 637922 10756 6315 1...
# 9998  10756 1991 1991 658439 630524 635285 1991 3846...
# 9999  2000 12802 603921 642835 636322 2000 642713 63...
#
#                                             prev_clicks  \
# 0     628813 609367 633423 660704 641747 648224 2757...
# 1     645617 24786 21372 626581 660737 630524 648974...
# 2     22736 28733 641642 615051 23821 10406 638013 2...
# 3     17157 616602 17138 618758 7540 1410 620125 650...
# 4     16732 2870 657351 652216 659131 641740 641739 ...
# ...                                                 ...
# 9995  622663 8516 620116 637127 10756 656939 10592 8...
# 9996  25018 12721 641853 653539 625003 601973 642301...
# 9997                                      603153 642029
# 9998  20831 654701 19548 633502 645891 26358 27306 1...
# 9999  931 11949 620116 25281 8884 11949 639298 63574...
#
#                                             freq_clicks  \
# 0     630197 9780 628813 605768 602533 17190 9766 65...
# 1     21372 28492 645617 630524 1106 24786 630936 64...
# 2     638013 601508 637971 601775 14379 20049 24930 ...
# 3     12470 7540 627143 17422 17157 620709 17138 628...
# 4     502335 653330 621984 601460 627198 640973 6501...
# ...                                                 ...
# 9995  8516 16904 623314 659209 10592 10756 616602 62...
# 9996                                         18574 9876
# 9997                                 no_frequent_clicks
# 9998  23597 645757 10406 27306 17474 600843 1863 259...
# 9999                           639298 635747 7020 11949
#
#                                             freq_chains  order_hour  \
# 0     7614 2241 18430 630134 648549 633575 10406 121...          21
# 1                                    no_frequent_orders           8
# 2     640577 640056 645856 4356 655414 10756 18574 6...          16
# 3     1991 10694 655087 620116 620198 630936 1108 65...          14
# 4     11847 603921 651009 638018 6501 16810 24580 25...          21
# ...                                                 ...         ...
# 9995                                 no_frequent_orders          10
# 9996             931 10406 621006 3288 620225 9956 1968          19
# 9997  10756 637922 12092 637966 649695 6315 620064 6...          13
# 9998  630524 1991 10584 606529 620116 12991 3846 658439          18
# 9999                                 no_frequent_orders           8
#
#       order_weekday geohash6  \
# 0                 5   thqehh
# 1                 6   thrryp
# 2                 6   thrdh4
# 3                 6   thqffq
# 4                 5   thrnwz
# ...             ...      ...
# 9995              6   thr8um
# 9996              6   thrrhv
# 9997              6   thx2jf
# 9998              6   thrrz4
# 9999              6   thx2hm
#
#                                           prev_searches
# 0     ramadan aqua mc donalds burger chicano vapiano...
# 1     bubble tea thai food sushi now junior seafood ...
# 2     al fanar burger king minis japaneese curry sus...
# 3     hardees lgaimat subway khfayef pizza ice cream...
# 4     rawabi alsham barbar elsayed hanfy abu tariq c...
# ...                                                 ...
# 9995  كيك عيد ميلاد McDonnell McDonnell كيك محلات كي...
# 9996  shake shack laffah macdonald baskin robbins br...
# 9997  macdonald zero starbucks water baskin robbins ...
# 9998  minimelts ماكدونالدز triangles bites فريز كناف...
# 9999  باب الحارة عجمان subway بابا جونز قصر الشوكولا...
#
# [10000 rows x 8 columns]. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       9876 1106 617960 25817 636322 7043 7614 619528...
# 1       26225 11877 28504 636829 28504 24210 629162 25...
# 2       10756 18574 10465 655413 661432 647662 13265 1...
# 3       1991 1991 655089 2000 655087 10694 620198 1069...
# 4       638192 608113 6501 621527 600608 12709 621527 ...
#                               ...
# 9995                                        655703 655703
# 9996    931 3288 10756 931 27063 621006 931 931 10406 ...
# 9997    10756 649695 649695 637922 637922 10756 6315 1...
# 9998    10756 1991 1991 658439 630524 635285 1991 3846...
# 9999    2000 12802 603921 642835 636322 2000 642713 63...
# Name: user_prev_chains, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       ramadan aqua mc donalds burger chicano vapiano...
# 1       bubble tea thai food sushi now junior seafood ...
# 2       al fanar burger king minis japaneese curry sus...
# 3       hardees lgaimat subway khfayef pizza ice cream...
# 4       rawabi alsham barbar elsayed hanfy abu tariq c...
#                               ...
# 9995    كيك عيد ميلاد McDonnell McDonnell كيك محلات كي...
# 9996    shake shack laffah macdonald baskin robbins br...
# 9997    macdonald zero starbucks water baskin robbins ...
# 9998    minimelts ماكدونالدز triangles bites فريز كناف...
# 9999    باب الحارة عجمان subway بابا جونز قصر الشوكولا...
# Name: prev_searches, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       628813 609367 633423 660704 641747 648224 2757...
# 1       645617 24786 21372 626581 660737 630524 648974...
# 2       22736 28733 641642 615051 23821 10406 638013 2...
# 3       17157 616602 17138 618758 7540 1410 620125 650...
# 4       16732 2870 657351 652216 659131 641740 641739 ...
#                               ...
# 9995    622663 8516 620116 637127 10756 656939 10592 8...
# 9996    25018 12721 641853 653539 625003 601973 642301...
# 9997                                        603153 642029
# 9998    20831 654701 19548 633502 645891 26358 27306 1...
# 9999    931 11949 620116 25281 8884 11949 639298 63574...
# Name: prev_clicks, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       21
# 1        8
# 2       16
# 3       14
# 4       21
#         ..
# 9995    10
# 9996    19
# 9997    13
# 9998    18
# 9999     8
# Name: order_hour, Length: 10000, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       5
# 1       6
# 2       6
# 3       6
# 4       5
#        ..
# 9995    6
# 9996    6
# 9997    6
# 9998    6
# 9999    6
# Name: order_weekday, Length: 10000, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       630197 9780 628813 605768 602533 17190 9766 65...
# 1       21372 28492 645617 630524 1106 24786 630936 64...
# 2       638013 601508 637971 601775 14379 20049 24930 ...
# 3       12470 7540 627143 17422 17157 620709 17138 628...
# 4       502335 653330 621984 601460 627198 640973 6501...
#                               ...
# 9995    8516 16904 623314 659209 10592 10756 616602 62...
# 9996                                           18574 9876
# 9997                                   no_frequent_clicks
# 9998    23597 645757 10406 27306 17474 600843 1863 259...
# 9999                             639298 635747 7020 11949
# Name: freq_clicks, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       7614 2241 18430 630134 648549 633575 10406 121...
# 1                                      no_frequent_orders
# 2       640577 640056 645856 4356 655414 10756 18574 6...
# 3       1991 10694 655087 620116 620198 630936 1108 65...
# 4       11847 603921 651009 638018 6501 16810 24580 25...
#                               ...
# 9995                                   no_frequent_orders
# 9996               931 10406 621006 3288 620225 9956 1968
# 9997    10756 637922 12092 637966 649695 6315 620064 6...
# 9998    630524 1991 10584 606529 620116 12991 3846 658439
# 9999                                   no_frequent_orders
# Name: freq_chains, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       thqehh
# 1       thrryp
# 2       thrdh4
# 3       thqffq
# 4       thrnwz
#          ...
# 9995    thr8um
# 9996    thrrhv
# 9997    thx2jf
# 9998    thrrz4
# 9999    thx2hm
# Name: geohash6, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       630197 9780 628813 605768 602533 17190 9766 65...
# 1       21372 28492 645617 630524 1106 24786 630936 64...
# 2       638013 601508 637971 601775 14379 20049 24930 ...
# 3       12470 7540 627143 17422 17157 620709 17138 628...
# 4       502335 653330 621984 601460 627198 640973 6501...
#                               ...
# 9995    8516 16904 623314 659209 10592 10756 616602 62...
# 9996                                           18574 9876
# 9997                                   no_frequent_clicks
# 9998    23597 645757 10406 27306 17474 600843 1863 259...
# 9999                             639298 635747 7020 11949
# Name: freq_clicks, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       7614 2241 18430 630134 648549 633575 10406 121...
# 1                                      no_frequent_orders
# 2       640577 640056 645856 4356 655414 10756 18574 6...
# 3       1991 10694 655087 620116 620198 630936 1108 65...
# 4       11847 603921 651009 638018 6501 16810 24580 25...
#                               ...
# 9995                                   no_frequent_orders
# 9996               931 10406 621006 3288 620225 9956 1968
# 9997    10756 637922 12092 637966 649695 6315 620064 6...
# 9998    630524 1991 10584 606529 620116 12991 3846 658439
# 9999                                   no_frequent_orders
# Name: freq_chains, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0       9876 1106 617960 25817 636322 7043 7614 619528...
# 1       26225 11877 28504 636829 28504 24210 629162 25...
# 2       10756 18574 10465 655413 661432 647662 13265 1...
# 3       1991 1991 655089 2000 655087 10694 620198 1069...
# 4       638192 608113 6501 621527 600608 12709 621527 ...
#                               ...
# 9995                                        655703 655703
# 9996    931 3288 10756 931 27063 621006 931 931 10406 ...
# 9997    10756 649695 649695 637922 637922 10756 6315 1...
# 9998    10756 1991 1991 658439 630524 635285 1991 3846...
# 9999    2000 12802 603921 642835 636322 2000 642713 63...
# Name: user_prev_chains, Length: 10000, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=       chain_id                  chain_name  \
# 0        660257                      Crowds
# 192      655420                  McDonald's
# 1236       2599                    WingStop
# 6315     660159                  McDonald's
# 6707      23254   Flame And Bake Restaurant
# ...         ...                         ...
# 699994   662509           Hinoki Restaurant
# 699995   660684  COCOMA RESTAURANT AND CAFE
# 699996   660136   8Bird - Nashville Chicken
# 699997   624735         GB Italian Pizzeria
# 699998   652949        Kal Ala Kaifk Snacks
#
#                                      tlabel
# 0                 burgers american fastfood
# 192               burgers american fastfood
# 1236              burgers american fastfood
# 6315              burgers american fastfood
# 6707                      shawarma lebanese
# ...                                     ...
# 699994           noodles thai asian chinese
# 699995  lebanese grills sandwiches shawarma
# 699996     burgers american fastfood snacks
# 699997          pizza italian pasta healthy
# 699998          filipino sandwiches seafood
#
# [8035 rows x 3 columns]. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0         660257
# 192       655420
# 1236        2599
# 6315      660159
# 6707       23254
#            ...
# 699994    662509
# 699995    660684
# 699996    660136
# 699997    624735
# 699998    652949
# Name: chain_id, Length: 8035, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0                   burgers american fastfood
# 192                 burgers american fastfood
# 1236                burgers american fastfood
# 6315                burgers american fastfood
# 6707                        shawarma lebanese
#                          ...
# 699994             noodles thai asian chinese
# 699995    lebanese grills sandwiches shawarma
# 699996       burgers american fastfood snacks
# 699997            pizza italian pasta healthy
# 699998            filipino sandwiches seafood
# Name: tlabel, Length: 8035, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0                             Crowds
# 192                       McDonald's
# 1236                        WingStop
# 6315                      McDonald's
# 6707       Flame And Bake Restaurant
#                      ...
# 699994             Hinoki Restaurant
# 699995    COCOMA RESTAURANT AND CAFE
# 699996     8Bird - Nashville Chicken
# 699997           GB Italian Pizzeria
# 699998          Kal Ala Kaifk Snacks
# Name: chain_name, Length: 8035, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0         660257
# 192       655420
# 1236        2599
# 6315      660159
# 6707       23254
#            ...
# 699994    662509
# 699995    660684
# 699996    660136
# 699997    624735
# 699998    652949
# Name: chain_id, Length: 8035, dtype: object. Consider rewriting this model with the Functional API.
# True
# True

# %%
# %timeit user_model(test_df[query_features].iloc[:1]).numpy()
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
# ...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=                                    user_prev_chains  \
# 0  9876 1106 617960 25817 636322 7043 7614 619528...
#
#                                          prev_clicks  \
# 0  628813 609367 633423 660704 641747 648224 2757...
#
#                                          freq_clicks  \
# 0  630197 9780 628813 605768 602533 17190 9766 65...
#
#                                          freq_chains  order_hour  \
# 0  7614 2241 18430 630134 648549 633575 10406 121...          21
#
#    order_weekday geohash6                                      prev_searches
# 0              5   thqehh  ramadan aqua mc donalds burger chicano vapiano...  . Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    ramadan aqua mc donalds burger chicano vapiano...
# Name: prev_searches, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    628813 609367 633423 660704 641747 648224 2757...
# Name: prev_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    21
# Name: order_hour, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    5
# Name: order_weekday, dtype: int64. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    thqehh
# Name: geohash6, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    630197 9780 628813 605768 602533 17190 9766 65...
# Name: freq_clicks, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    7614 2241 18430 630134 648549 633575 10406 121...
# Name: freq_chains, dtype: object. Consider rewriting this model with the Functional API.
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor. Received: inputs=0    9876 1106 617960 25817 636322 7043 7614 619528...
# Name: user_prev_chains, dtype: object. Consider rewriting this model with the Functional API.
# 69.7 ms ± 6.32 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
