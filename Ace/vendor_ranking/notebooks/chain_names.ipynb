# %%
import pandas as pd
import polars as pl
import numpy as np

# %%
from pathlib import Path

chains_embeddings_path = Path(
    "../../tests/fixtures/vendor_ranking/two_towers/inference_model_artifacts/AE/model_artifacts_recall_4858/tt_chain_embeddings_recall@10_4858.parquet"
)
assert chains_embeddings_path.exists()

# %%
from vendor_ranking.two_tower.model_artifacts import SourceCloudType, ArtifactsManager
from vendor_ranking.two_tower.artifacts_service import ArtifactsService
from vendor_ranking.data import refresh_vendors, get_all_vendors

country = "AE"
config = ArtifactsService.configs[country]
artifacts_manager = VendorArtifactsManager(
    recall=config.recall,
    base_dir="",
    country=country,
    version=config.version,
    source=SourceCloudType.AWS,
)
artifacts_manager.chain_embeddings_local_path = chains_embeddings_path
chain_embeddings: "pl.DataFrame" = ArtifactsService._load_chains_embeddings(artifacts_manager)

# %%
chain_embeddings
# Out:
# shape: (8_798, 2)
# ┌───────────────────────────────────┬──────────┐
# │ chain_embeddings                  ┆ chain_id │
# │ ---                               ┆ ---      │
# │ list[f32]                         ┆ i64      │
# ╞═══════════════════════════════════╪══════════╡
# │ [0.029733, 0.193347, … 0.03776]   ┆ 28525    │
# │ [0.060471, 0.267316, … 0.175063]  ┆ 2000     │
# │ [-0.011328, 0.055134, … -0.03688… ┆ 6544     │
# │ [-0.096245, 0.211634, … 0.024418… ┆ 10581    │
# │ …                                 ┆ …        │
# │ [-0.147472, 0.125612, … 0.101698… ┆ 665671   │
# │ [-0.084697, 0.441283, … 0.019612… ┆ 665406   │
# │ [-0.092685, 0.3433, … -0.069334]  ┆ 665735   │
# │ [-0.108035, 0.354954, … -0.17012… ┆ 657865   │
# └───────────────────────────────────┴──────────┘

# %%
from vendor_ranking.two_tower.artifacts_service import CHAIN_NAME, CHAIN_ID
from vendor_ranking import SERVICE_NAME
from ace import db
import asyncio


async def load_vendors_from_db() -> "pl.DataFrame":
    await refresh_vendors()
    return get_all_vendors()


await db.init_connection_pool(service_name=SERVICE_NAME, query_timeout=150_000)
all_vendors: "pl.DataFrame" = await load_vendors_from_db()
all_vendors = all_vendors.select([CHAIN_ID, CHAIN_NAME]).unique(
    [
        CHAIN_ID,
    ],
    keep="first",
)
# Out:
# 2023-08-07 12:55:20 [info     ] Check if latest dynamic ranking vendor data is refreshed after 2023-04-28...
# 2023-08-07 12:55:20 [info     ] Skipping dynamic ranking data refresh...

# %%
all_vendors.shape
# Out:
# (181, 2)

# %%
chain_embeddings, all_vendors
# Out:
# (shape: (8_798, 2)
#  ┌───────────────────────────────────┬──────────┐
#  │ chain_embeddings                  ┆ chain_id │
#  │ ---                               ┆ ---      │
#  │ list[f32]                         ┆ i64      │
#  ╞═══════════════════════════════════╪══════════╡
#  │ [0.029733, 0.193347, … 0.03776]   ┆ 28525    │
#  │ [0.060471, 0.267316, … 0.175063]  ┆ 2000     │
#  │ [-0.011328, 0.055134, … -0.03688… ┆ 6544     │
#  │ [-0.096245, 0.211634, … 0.024418… ┆ 10581    │
#  │ …                                 ┆ …        │
#  │ [-0.147472, 0.125612, … 0.101698… ┆ 665671   │
#  │ [-0.084697, 0.441283, … 0.019612… ┆ 665406   │
#  │ [-0.092685, 0.3433, … -0.069334]  ┆ 665735   │
#  │ [-0.108035, 0.354954, … -0.17012… ┆ 657865   │
#  └───────────────────────────────────┴──────────┘,
#  shape: (181, 2)
#  ┌──────────┬─────────────────────────┐
#  │ chain_id ┆ chain_name              │
#  │ ---      ┆ ---                     │
#  │ i64      ┆ str                     │
#  ╞══════════╪═════════════════════════╡
#  │ 23520    ┆ So Ghawi                │
#  │ 621754   ┆ Tikka Taj               │
#  │ 624387   ┆ Beirut 65               │
#  │ 622059   ┆ Nara Cafe Pizza & Pasta │
#  │ …        ┆ …                       │
#  │ 2576     ┆ The Pizza Company       │
#  │ 649247   ┆ Halla Food              │
#  │ 3365     ┆ Subway                  │
#  │ 7988     ┆ Al Safeer Restaurant    │
#  └──────────┴─────────────────────────┘)

# %%
joined = chain_embeddings.join(all_vendors, on="chain_id", how="left").select(chain_embeddings.columns + ["chain_name"])
joined.shape
# Out:
# (8798, 3)

# %%
xx = joined[CHAIN_ID].sort()
yy = chain_embeddings[CHAIN_ID].sort()
for idx, (x, y) in enumerate(zip(xx, yy)):
    assert x == y, idx
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 4
#       2 yy = chain_embeddings[CHAIN_ID].sort()
#       3 for idx, (x, y) in enumerate(zip(xx, yy)):
# ----> 4     assert x == y, idx
#
# AssertionError: 647

# %%
xx[647], yy[647]
# Out:
# (10181, 10184)

# %%
joined.filter(pl.col(CHAIN_ID).is_in([10181, 10184])), chain_embeddings.filter(
    pl.col(CHAIN_ID).is_in([10181, 10184])
), all_vendors.filter(pl.col(CHAIN_ID).is_in([10181, 10184]))
# Out:
# (shape: (3, 3)
#  ┌───────────────────────────────────┬──────────┬─────────────────────────┐
#  │ chain_embeddings                  ┆ chain_id ┆ chain_name              │
#  │ ---                               ┆ ---      ┆ ---                     │
#  │ list[f32]                         ┆ i64      ┆ str                     │
#  ╞═══════════════════════════════════╪══════════╪═════════════════════════╡
#  │ [-0.120137, 0.279757, … -0.10439… ┆ 10181    ┆ Nom Nom Asia Restaurant │
#  │ [-0.120137, 0.279757, … -0.10439… ┆ 10181    ┆ NomNom Asia             │
#  │ [-0.121796, 0.276462, … 0.104862… ┆ 10184    ┆ null                    │
#  └───────────────────────────────────┴──────────┴─────────────────────────┘,
#  shape: (2, 2)
#  ┌───────────────────────────────────┬──────────┐
#  │ chain_embeddings                  ┆ chain_id │
#  │ ---                               ┆ ---      │
#  │ list[f32]                         ┆ i64      │
#  ╞═══════════════════════════════════╪══════════╡
#  │ [-0.120137, 0.279757, … -0.10439… ┆ 10181    │
#  │ [-0.121796, 0.276462, … 0.104862… ┆ 10184    │
#  └───────────────────────────────────┴──────────┘,
#  shape: (2, 2)
#  ┌──────────┬─────────────────────────┐
#  │ chain_id ┆ chain_name              │
#  │ ---      ┆ ---                     │
#  │ i64      ┆ str                     │
#  ╞══════════╪═════════════════════════╡
#  │ 10181    ┆ Nom Nom Asia Restaurant │
#  │ 10181    ┆ NomNom Asia             │
#  └──────────┴─────────────────────────┘)

# %%
joined
# Out:
# shape: (8_798, 3)
# ┌───────────────────────────────────┬──────────┬────────────┐
# │ chain_embeddings                  ┆ chain_id ┆ chain_name │
# │ ---                               ┆ ---      ┆ ---        │
# │ list[f32]                         ┆ i64      ┆ str        │
# ╞═══════════════════════════════════╪══════════╪════════════╡
# │ [0.029733, 0.193347, … 0.03776]   ┆ 28525    ┆ null       │
# │ [0.060471, 0.267316, … 0.175063]  ┆ 2000     ┆ null       │
# │ [-0.011328, 0.055134, … -0.03688… ┆ 6544     ┆ null       │
# │ [-0.096245, 0.211634, … 0.024418… ┆ 10581    ┆ null       │
# │ …                                 ┆ …        ┆ …          │
# │ [-0.147472, 0.125612, … 0.101698… ┆ 665671   ┆ null       │
# │ [-0.084697, 0.441283, … 0.019612… ┆ 665406   ┆ null       │
# │ [-0.092685, 0.3433, … -0.069334]  ┆ 665735   ┆ null       │
# │ [-0.108035, 0.354954, … -0.17012… ┆ 657865   ┆ null       │
# └───────────────────────────────────┴──────────┴────────────┘

# %%
chains_without_names = joined.filter(pl.col(CHAIN_NAME).is_null())[CHAIN_ID]

# %%
f"{list(chains_without_names)}"
# Out:
# '[28525, 2000, 6544, 10581, 13187, 620392, 634349, 655701, 10241, 6501, 10501, 8516, 18574, 619777, 661685, 711, 632368, 656721, 1991, 1968, 641136, 1106, 12838, 629162, 633557, 7540, 618873, 663020, 660015, 3219, 653862, 18876, 632024, 3006, 659005, 11198, 11179, 658439, 652384, 601419, 660505, 661295, 636322, 632016, 14354, 14542, 9804, 2599, 10636, 630435, 659745, 27682, 662552, 650136, 12802, 633299, 648114, 627543, 22849, 14420, 658475, 7700, 602102, 19122, 639298, 648670, 629725, 660567, 656411, 23254, 650453, 18741, 630398, 660851, 10782, 629666, 653734, 10065, 642835, 655491, 9694, 16810, 2699, 18897, 5699, 655086, 645526, 16311, 10329, 27575, 659652, 28448, 28514, 640347, 27962, 661724, 619156, 642713, 658301, 612648, 611005, 618704, 8722, 650182, 620064, 663892, 663177, 626084, 15456, 654979, 19056, 24702, 637893, 11076, 645659, 620116, 17676, 658394, 10388, 623304, 9275, 11698, 11277, 654974, 12045, 9869, 604911, 931, 647885, 25053, 663596, 626896, 21974, 618254, 9759, 613438, 19486, 609651, 390, 19452, 13265, 28017, 25817, 657310, 28492, 607598, 602369, 621002, 614622, 3929, 961, 645987, 629546, 660115, 654186, 626840, 603921, 9956, 647305, 620227, 641747, 658090, 2618, 629661, 653962, 21151, 6640, 641371, 661195, 661932, 645278, 654608, 21103, 3116, 653479, 642260, 13520, 657315, 658516, 637783, 494, 636143, 19785, 1410, 2954, 661241, 654767, 601186, 13324, 8740, 14455, 601837, 654999, 662372, 641537, 655700, 647686, 630530, 661194, 643605, 619528, 646403, 21372, 636069, 3618, 9807, 9876, 23857, 8815, 642128, 652641, 601787, 20455, 632443, 10390, 10406, 650877, 621870, 3265, 10926, 645693, 5801, 641629, 620125, 1619, 622120, 644818, 26053, 20193, 625665, 635169, 626230, 7440, 25281, 15326, 1064, 21371, 16335, 1854, 10163, 652219, 633025, 655414, 662244, 655703, 655413, 11299, 640661, 26366, 662083, 640802, 660159, 15441, 643159, 601399, 7517, 649084, 657822, 624363, 655000, 663436, 633563, 2419, 10756, 620136, 632445, 16075, 612383, 661196, 12092, 12721, 628838, 620225, 649164, 655001, 10465, 22386, 28170, 654783, 640377, 629438, 8718, 659187, 660926, 654061, 600361, 640322, 638336, 8759, 23592, 10590, 8029, 638798, 7095, 653733, 664157, 631545, 646787, 638132, 600594, 648546, 657587, 9610, 623191, 11251, 628474, 645134, 621497, 620682, 9107, 1507, 653007, 18303, 644197, 606726, 3658, 27261, 620062, 655089, 653366, 11272, 661253, 1646, 627138, 625911, 661380, 20049, 600654, 7807, 629452, 641804, 621139, 655416, 18311, 9439, 8736, 20127, 630222, 619504, 602897, 12579, 659663, 21751, 661662, 613463, 647485, 661247, 660902, 629390, 634648, 657139, 631761, 6331, 663392, 14385, 656900, 27678, 647316, 620933, 1931, 8124, 23735, 625655, 639077, 654973, 659678, 22821, 632879, 607490, 621771, 629014, 624761, 25020, 1192, 642418, 23442, 2913, 651770, 22278, 641685, 630980, 650356, 654382, 664801, 634192, 13950, 938, 17422, 19369, 2951, 652828, 601775, 618874, 652466, 1826, 4530, 13421, 653937, 28869, 656116, 652859, 28777, 617316, 652643, 4001, 626099, 28705, 639867, 2677, 16406, 635647, 663068, 644840, 22965, 27040, 661224, 655800, 661833, 12446, 18430, 653681, 622876, 615199, 613091, 934, 21734, 11129, 622167, 654165, 615161, 18918, 631957, 1108, 13431, 628197, 28504, 653165, 2344, 633058, 615051, 644964, 28225, 654977, 26997, 600099, 633558, 3107, 654946, 647760, 654975, 9542, 651887, 637943, 10694, 650479, 9418, 619451, 661850, 18762, 652017, 624182, 6377, 11345, 656369, 664644, 662206, 660141, 636831, 619778, 21448, 654720, 651837, 656810, 4395, 19901, 618698, 654659, 16743, 655502, 639900, 656880, 662686, 14705, 621006, 13850, 645823, 15980, 26568, 659579, 25930, 623724, 600975, 4095, 642087, 600787, 664240, 1375, 10043, 658454, 620808, 649658, 636179, 607654, 660248, 3823, 27505, 661887, 7094, 661889, 12106, 632011, 637127, 621003, 625508, 657852, 18715, 10584, 18010, 633694, 658144, 1594, 655555, 629033, 621116, 27518, 2283, 9686, 10379, 660845, 627570, 9756, 12422, 655420, 616602, 19561, 626995, 22384, 640415, 2278 ...
